# %% [markdown]
# # 1. Load Libraries

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
# custom libraries
import db_manager as db
import ticker

# %% [markdown]
# # 1. Data Pre-Processing

# %%
conn = db.connectToDB()
df = db.getDailyPrices(1,conn=conn)
# Out:
# Connecting to the PostgreSQL database...

# %%
# View df
df
# Out:
#             date ticker        open       close         low        high  \
# 0     2013-01-02   AAPL   19.779285   19.608213   19.821428   19.343929
# 1     2013-01-03   AAPL   19.567142   19.360714   19.631071   19.321428
# 2     2013-01-04   AAPL   19.177500   18.821428   19.236786   18.779642
# 3     2013-01-07   AAPL   18.642857   18.710714   18.903570   18.400000
# 4     2013-01-08   AAPL   18.900356   18.761070   18.996071   18.616072
# ...          ...    ...         ...         ...         ...         ...
# 2584  2023-04-10   AAPL  161.419998  162.029999  162.029999  160.080002
# 2585  2023-04-11   AAPL  162.350006  160.800003  162.360001  160.509995
# 2586  2023-04-12   AAPL  161.220001  160.100006  162.059998  159.779999
# 2587  2023-04-13   AAPL  161.630005  165.559998  165.800003  161.419998
# 2588  2023-04-14   AAPL  164.589996  165.210007  166.320007  163.820007
#
#            volume
# 0     560518000.0
# 1     352965180.0
# 2     594333570.0
# 3     484156420.0
# 4     458707200.0
# ...           ...
# 2584   47716900.0
# 2585   47644200.0
# 2586   50133100.0
# 2587   68445600.0
# 2588   49337200.0
#
# [2589 rows x 7 columns]

# %%
# Keep only close
df2 = df['close']
df2
# Out:
# 0        19.608213
# 1        19.360714
# 2        18.821428
# 3        18.710714
# 4        18.761070
#            ...
# 2584    162.029999
# 2585    160.800003
# 2586    160.100006
# 2587    165.559998
# 2588    165.210007
# Name: close, Length: 2589, dtype: float64

# %%
df2.shape
# Out:
# (2589,)

# %%
# plot
plt.plot(df2)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df2 = scaler.fit_transform(np.array(df2).reshape(-1,1))

# %%
df2
# Out:
# array([[0.03368219],
#        [0.03220953],
#        [0.02900069],
#        ...,
#        [0.86963189],
#        [0.90211976],
#        [0.90003726]])

# %%
df2.shape
# Out:
# (2589, 1)

# %%
train_size = int(len(df2)*0.65)
test_size=len(df2)-train_size
train_data, test_data=df2[0:train_size,:],df2[train_size:len(df2),:1]

# %%
train_size,test_size
# Out:
# (1682, 907)

# %%
# convert an array of values into dataset matrix
def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset)-time_step-1):
        X.append(dataset[i:(i+time_step),0])
        Y.append(dataset[i+time_step,0])
    return np.array(X), np.array(Y)

# %%
TIME_STEP=60
X_train, y_train = create_dataset(train_data,TIME_STEP)
X_test, y_test = create_dataset(test_data, TIME_STEP)

# %%
print(X_train)
# Out:
# [[0.03368219 0.03220953 0.02900069 ... 0.01500505 0.01307974 0.01107794]
#  [0.03220953 0.02900069 0.02834192 ... 0.01307974 0.01107794 0.00815598]
#  [0.02900069 0.02834192 0.02864155 ... 0.01107794 0.00815598 0.00834299]
#  ...
#  [0.19986612 0.20348085 0.20679807 ... 0.22274452 0.22792116 0.22751954]
#  [0.20348085 0.20679807 0.2058758  ... 0.22792116 0.22751954 0.2229974 ]
#  [0.20679807 0.2058758  0.20581628 ... 0.22751954 0.2229974  0.22818893]]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1621, 60)
# (846, 60)

# %%
# Reshape to include additional dimension
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_train)
# Out:
# (1621, 60, 1)
# (846, 60, 1)
# [[[0.03368219]
#   [0.03220953]
#   [0.02900069]
#   ...
#   [0.01500505]
#   [0.01307974]
#   [0.01107794]]
#
#  [[0.03220953]
#   [0.02900069]
#   [0.02834192]
#   ...
#   [0.01307974]
#   [0.01107794]
#   [0.00815598]]
#
#  [[0.02900069]
#   [0.02834192]
#   [0.02864155]
#   ...
#   [0.01107794]
#   [0.00815598]
#   [0.00834299]]
#
#  ...
#
#  [[0.19986612]
#   [0.20348085]
#   [0.20679807]
#   ...
#   [0.22274452]
#   [0.22792116]
#   [0.22751954]]
#
#  [[0.20348085]
#   [0.20679807]
#   [0.2058758 ]
#   ...
#   [0.22792116]
#   [0.22751954]
#   [0.2229974 ]]
#
#  [[0.20679807]
#   [0.2058758 ]
#   [0.20581628]
#   ...
#   [0.22751954]
#   [0.2229974 ]
#   [0.22818893]]]

# %% [markdown]
# # 2. LSTM Model Architecture

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(TIME_STEP,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_23 (LSTM)              (None, 60, 50)            10400
#
#  lstm_24 (LSTM)              (None, 60, 50)            20200
#
#  lstm_25 (LSTM)              (None, 50)                20200
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Training

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 5s 91ms/step - loss: 0.0027 - val_loss: 0.0157
# Epoch 2/100
# 26/26 [==============================] - 2s 68ms/step - loss: 1.9196e-04 - val_loss: 0.0071
# Epoch 3/100
# 26/26 [==============================] - 2s 67ms/step - loss: 1.0038e-04 - val_loss: 0.0038
# Epoch 4/100
# 26/26 [==============================] - 2s 68ms/step - loss: 9.8762e-05 - val_loss: 0.0053
# Epoch 5/100
# 26/26 [==============================] - 2s 70ms/step - loss: 8.9177e-05 - val_loss: 0.0054
# Epoch 6/100
# 26/26 [==============================] - 2s 72ms/step - loss: 8.8772e-05 - val_loss: 0.0052
# Epoch 7/100
# 26/26 [==============================] - 2s 70ms/step - loss: 8.5861e-05 - val_loss: 0.0058
# Epoch 8/100
# 26/26 [==============================] - 2s 73ms/step - loss: 8.2657e-05 - val_loss: 0.0063
# Epoch 9/100
# 26/26 [==============================] - 2s 70ms/step - loss: 7.5537e-05 - val_loss: 0.0084
# Epoch 10/100
# 26/26 [==============================] - 2s 70ms/step - loss: 7.1815e-05 - val_loss: 0.0072
# Epoch 11/100
# 26/26 [==============================] - 2s 71ms/step - loss: 6.9517e-05 - val_loss: 0.0099
# Epoch 12/100
# 26/26 [==============================] - 2s 70ms/step - loss: 6.4797e-05 - val_loss: 0.0106
# Epoch 13/100
# 26/26 [==============================] - 2s 70ms/step - loss: 6.1165e-05 - val_loss: 0.0126
# Epoch 14/100
# 26/26 [==============================] - 2s 70ms/step - loss: 6.7750e-05 - val_loss: 0.0155
# Epoch 15/100
# 26/26 [==============================] - 2s 70ms/step - loss: 6.4440e-05 - val_loss: 0.0137
# Epoch 16/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.6419e-05 - val_loss: 0.0118
# Epoch 17/100
# 26/26 [==============================] - 2s 69ms/step - loss: 6.2457e-05 - val_loss: 0.0199
# Epoch 18/100
# 26/26 [==============================] - 2s 72ms/step - loss: 5.9682e-05 - val_loss: 0.0062
# Epoch 19/100
# 26/26 [==============================] - 2s 70ms/step - loss: 6.1300e-05 - val_loss: 0.0079
# Epoch 20/100
# 26/26 [==============================] - 2s 70ms/step - loss: 5.1872e-05 - val_loss: 0.0101
# Epoch 21/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.3356e-05 - val_loss: 0.0074
# Epoch 22/100
# 26/26 [==============================] - 2s 70ms/step - loss: 5.4966e-05 - val_loss: 0.0066
# Epoch 23/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.9732e-05 - val_loss: 0.0056
# Epoch 24/100
# 26/26 [==============================] - 2s 70ms/step - loss: 5.0326e-05 - val_loss: 0.0051
# Epoch 25/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.1699e-05 - val_loss: 0.0044
# Epoch 26/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.9899e-05 - val_loss: 0.0067
# Epoch 27/100
# 26/26 [==============================] - 2s 70ms/step - loss: 4.9911e-05 - val_loss: 0.0033
# Epoch 28/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.0127e-05 - val_loss: 0.0044
# Epoch 29/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.9917e-05 - val_loss: 0.0052
# Epoch 30/100
# 26/26 [==============================] - 2s 70ms/step - loss: 5.1702e-05 - val_loss: 0.0046
# Epoch 31/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.8138e-05 - val_loss: 0.0057
# Epoch 32/100
# 26/26 [==============================] - 2s 70ms/step - loss: 4.8177e-05 - val_loss: 0.0050
# Epoch 33/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.8179e-05 - val_loss: 0.0040
# Epoch 34/100
# 26/26 [==============================] - 2s 70ms/step - loss: 4.9615e-05 - val_loss: 0.0066
# Epoch 35/100
# 26/26 [==============================] - 2s 71ms/step - loss: 5.1351e-05 - val_loss: 0.0039
# Epoch 36/100
# 26/26 [==============================] - 2s 72ms/step - loss: 4.7711e-05 - val_loss: 0.0044
# Epoch 37/100
# 26/26 [==============================] - 2s 72ms/step - loss: 5.0505e-05 - val_loss: 0.0029
# Epoch 38/100
# 26/26 [==============================] - 2s 72ms/step - loss: 4.6105e-05 - val_loss: 0.0022
# Epoch 39/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.4676e-05 - val_loss: 8.6491e-04
# Epoch 40/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.4441e-05 - val_loss: 0.0019
# Epoch 41/100
# 26/26 [==============================] - 2s 70ms/step - loss: 3.9944e-05 - val_loss: 0.0011
# Epoch 42/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.0618e-05 - val_loss: 0.0015
# Epoch 43/100
# 26/26 [==============================] - 2s 72ms/step - loss: 4.0006e-05 - val_loss: 9.8543e-04
# Epoch 44/100
# 26/26 [==============================] - 2s 70ms/step - loss: 4.4888e-05 - val_loss: 0.0010
# Epoch 45/100
# 26/26 [==============================] - 2s 74ms/step - loss: 4.0421e-05 - val_loss: 0.0026
# Epoch 46/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.8471e-05 - val_loss: 0.0015
# Epoch 47/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.2653e-05 - val_loss: 0.0015
# Epoch 48/100
# 26/26 [==============================] - 2s 71ms/step - loss: 3.6818e-05 - val_loss: 0.0012
# Epoch 49/100
# 26/26 [==============================] - 173s 79ms/step - loss: 3.5313e-05 - val_loss: 0.0018
# Epoch 50/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.6953e-05 - val_loss: 0.0027
# Epoch 51/100
# 26/26 [==============================] - 2s 72ms/step - loss: 3.8602e-05 - val_loss: 0.0028
# Epoch 52/100
# 26/26 [==============================] - 2s 72ms/step - loss: 3.7595e-05 - val_loss: 0.0012
# Epoch 53/100
# 26/26 [==============================] - 2s 71ms/step - loss: 4.3175e-05 - val_loss: 0.0017
# Epoch 54/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.5002e-05 - val_loss: 9.9428e-04
# Epoch 55/100
# 26/26 [==============================] - 2s 72ms/step - loss: 3.6370e-05 - val_loss: 8.2989e-04
# Epoch 56/100
# 26/26 [==============================] - 2s 71ms/step - loss: 3.4429e-05 - val_loss: 0.0013
# Epoch 57/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.2353e-05 - val_loss: 9.5965e-04
# Epoch 58/100
# 26/26 [==============================] - 2s 71ms/step - loss: 3.2017e-05 - val_loss: 9.1145e-04
# Epoch 59/100
# 26/26 [==============================] - 2s 71ms/step - loss: 3.0325e-05 - val_loss: 9.5989e-04
# Epoch 60/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.1892e-05 - val_loss: 0.0010
# Epoch 61/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.0989e-05 - val_loss: 9.1795e-04
# Epoch 62/100
# 26/26 [==============================] - 2s 74ms/step - loss: 3.2538e-05 - val_loss: 0.0017
# Epoch 63/100
# 26/26 [==============================] - 2s 75ms/step - loss: 4.6278e-05 - val_loss: 0.0012
# Epoch 64/100
# 26/26 [==============================] - 2s 73ms/step - loss: 3.1226e-05 - val_loss: 9.1251e-04
# Epoch 65/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.9375e-05 - val_loss: 0.0013
# Epoch 66/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.8155e-05 - val_loss: 0.0012
# Epoch 67/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.7167e-05 - val_loss: 9.9727e-04
# Epoch 68/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.9185e-05 - val_loss: 9.5971e-04
# Epoch 69/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.9249e-05 - val_loss: 0.0012
# Epoch 70/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.8400e-05 - val_loss: 0.0010
# Epoch 71/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.6586e-05 - val_loss: 9.8330e-04
# Epoch 72/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.9953e-05 - val_loss: 0.0011
# Epoch 73/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.5729e-05 - val_loss: 0.0029
# Epoch 74/100
# 26/26 [==============================] - 2s 72ms/step - loss: 3.0486e-05 - val_loss: 9.2062e-04
# Epoch 75/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.5624e-05 - val_loss: 9.3307e-04
# Epoch 76/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.4719e-05 - val_loss: 0.0017
# Epoch 77/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.4930e-05 - val_loss: 0.0011
# Epoch 78/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.4917e-05 - val_loss: 0.0014
# Epoch 79/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.3674e-05 - val_loss: 0.0011
# Epoch 80/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.6282e-05 - val_loss: 8.7094e-04
# Epoch 81/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.6243e-05 - val_loss: 0.0011
# Epoch 82/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.4944e-05 - val_loss: 9.9658e-04
# Epoch 83/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.6029e-05 - val_loss: 8.6768e-04
# Epoch 84/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.3605e-05 - val_loss: 0.0011
# Epoch 85/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.2288e-05 - val_loss: 9.6368e-04
# Epoch 86/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.3647e-05 - val_loss: 0.0011
# Epoch 87/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.2688e-05 - val_loss: 0.0020
# Epoch 88/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.2529e-05 - val_loss: 0.0014
# Epoch 89/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.1184e-05 - val_loss: 0.0011
# Epoch 90/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.1953e-05 - val_loss: 8.7833e-04
# Epoch 91/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.0902e-05 - val_loss: 0.0014
# Epoch 92/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.3214e-05 - val_loss: 8.7486e-04
# Epoch 93/100
# 26/26 [==============================] - 2s 72ms/step - loss: 3.0371e-05 - val_loss: 0.0032
# Epoch 94/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.4472e-05 - val_loss: 0.0013
# Epoch 95/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.1107e-05 - val_loss: 0.0014
# Epoch 96/100
# 26/26 [==============================] - 2s 72ms/step - loss: 2.2269e-05 - val_loss: 0.0034
# Epoch 97/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.3857e-05 - val_loss: 0.0014
# Epoch 98/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.0203e-05 - val_loss: 9.9052e-04
# Epoch 99/100
# 26/26 [==============================] - 2s 71ms/step - loss: 1.9858e-05 - val_loss: 7.2280e-04
# Epoch 100/100
# 26/26 [==============================] - 2s 71ms/step - loss: 2.1422e-05 - val_loss: 7.6762e-04

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.10.0'

# %% [markdown]
# # 4. Prediction

# %%
X_train
# Out:
# array([[[0.03368219],
#         [0.03220953],
#         [0.02900069],
#         ...,
#         [0.01500505],
#         [0.01307974],
#         [0.01107794]],
#
#        [[0.03220953],
#         [0.02900069],
#         [0.02834192],
#         ...,
#         [0.01307974],
#         [0.01107794],
#         [0.00815598]],
#
#        [[0.02900069],
#         [0.02834192],
#         [0.02864155],
#         ...,
#         [0.01107794],
#         [0.00815598],
#         [0.00834299]],
#
#        ...,
#
#        [[0.19986612],
#         [0.20348085],
#         [0.20679807],
#         ...,
#         [0.22274452],
#         [0.22792116],
#         [0.22751954]],
#
#        [[0.20348085],
#         [0.20679807],
#         [0.2058758 ],
#         ...,
#         [0.22792116],
#         [0.22751954],
#         [0.2229974 ]],
#
#        [[0.20679807],
#         [0.2058758 ],
#         [0.20581628],
#         ...,
#         [0.22751954],
#         [0.2229974 ],
#         [0.22818893]]])

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 51/51 [==============================] - 1s 10ms/step
# 27/27 [==============================] - 0s 9ms/step

# %%
# Transform
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
train_predict
# Out:
# array([[15.844549],
#        [15.563638],
#        [15.281086],
#        ...,
#        [50.82967 ],
#        [51.034138],
#        [51.175835]], dtype=float32)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 33.450201543295684

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 134.6858690626348

# %% [markdown]
# # 5. Comparing (Plotting)

# %%
LOOK_BACK=60
# plotting
trainPredictPlot = np.empty_like(df2)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[LOOK_BACK:len(train_predict)+LOOK_BACK,:] = train_predict
#Shift test predictions for plotting
testPredictPlot = np.empty_like(df2)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(LOOK_BACK*2)+1:len(df2)-1,:] = test_predict
# Plotting
plt.plot(scaler.inverse_transform(df2))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 907

# %%
train_predict
# Out:
# array([[15.844549],
#        [15.563638],
#        [15.281086],
#        ...,
#        [50.82967 ],
#        [51.034138],
#        [51.175835]], dtype=float32)

# %% [markdown]
# # 6. Future Prediction

# %%
test_data
# Out:
# array([[0.23559688],
#        [0.23936036],
#        [0.24960952],
#        [0.24886575],
#        [0.24240982],
#        [0.24412049],
#        [0.24531053],
#        [0.24838975],
#        [0.2456973 ],
#        [0.24089253],
#        [0.2423652 ],
#        [0.24081814],
#        [0.24580142],
#        [0.24410562],
#        [0.24251396],
#        [0.25017479],
#        [0.25109706],
#        [0.24272222],
#        [0.24548905],
#        [0.25469691],
#        [0.25477129],
#        [0.25081442],
#        [0.25472667],
#        [0.25927854],
#        [0.26838232],
#        [0.26787654],
#        [0.26705841],
#        [0.26564522],
#        [0.26699889],
#        [0.26867982],
#        [0.27477873],
#        [0.2739606 ],
#        [0.27875046],
#        [0.27934549],
#        [0.28380812],
#        [0.28748235],
#        [0.27891409],
#        [0.27886947],
#        [0.28705095],
#        [0.29755301],
#        [0.30005207],
#        [0.29950169],
#        [0.2996653 ],
#        [0.30292302],
#        [0.30397921],
#        [0.30704354],
#        [0.3066865 ],
#        [0.31042024],
#        [0.30769806],
#        [0.31233918],
#        [0.31433249],
#        [0.31312758],
#        [0.30851619],
#        [0.3067609 ],
#        [0.30641875],
#        [0.31324656],
#        [0.31015249],
#        [0.31543325],
#        [0.31455561],
#        [0.30995911],
#        [0.3029528 ],
#        [0.30635924],
#        [0.31207139],
#        [0.31970249],
#        [0.31406474],
#        [0.3163853 ],
#        [0.31979174],
#        [0.32081815],
#        [0.32630718],
#        [0.33331349],
#        [0.33413166],
#        [0.33313499],
#        [0.3335515 ],
#        [0.33268875],
#        [0.33947193],
#        [0.33987355],
#        [0.34826331],
#        [0.34809966],
#        [0.35065823],
#        [0.3538267 ],
#        [0.36379325],
#        [0.35944961],
#        [0.36297508],
#        [0.36087768],
#        [0.36801787],
#        [0.37759764],
#        [0.37863889],
#        [0.3885013 ],
#        [0.38213462],
#        [0.38014132],
#        [0.38594273],
#        [0.39113428],
#        [0.38792118],
#        [0.38960211],
#        [0.39187805],
#        [0.39050949],
#        [0.37658612],
#        [0.38958722],
#        [0.39947937],
#        [0.39878022],
#        [0.37741914],
#        [0.37615472],
#        [0.39131278],
#        [0.39518039],
#        [0.40077352],
#        [0.39306807],
#        [0.39532911],
#        [0.39244328],
#        [0.40373376],
#        [0.40026776],
#        [0.40038679],
#        [0.3915359 ],
#        [0.39840834],
#        [0.39346969],
#        [0.38268501],
#        [0.36056526],
#        [0.34554109],
#        [0.35233916],
#        [0.32388248],
#        [0.32364446],
#        [0.36150242],
#        [0.34738567],
#        [0.36734846],
#        [0.35274082],
#        [0.34695427],
#        [0.31294908],
#        [0.34146523],
#        [0.32672369],
#        [0.28626255],
#        [0.33050206],
#        [0.27730757],
#        [0.29314988],
#        [0.28394199],
#        [0.28113054],
#        [0.25801415],
#        [0.2507698 ],
#        [0.28425438],
#        [0.28223133],
#        [0.30145037],
#        [0.28553367],
#        [0.29605058],
#        [0.29527705],
#        [0.27537376],
#        [0.28135366],
#        [0.27611753],
#        [0.30744516],
#        [0.30292302],
#        [0.31280032],
#        [0.31565638],
#        [0.32348086],
#        [0.34400892],
#        [0.34011156],
#        [0.34347343],
#        [0.33768686],
#        [0.328955  ],
#        [0.31622165],
#        [0.32772036],
#        [0.32612868],
#        [0.33793976],
#        [0.33823729],
#        [0.33140944],
#        [0.34502048],
#        [0.35404983],
#        [0.34701378],
#        [0.35309782],
#        [0.35964299],
#        [0.36420976],
#        [0.368836  ],
#        [0.37834141],
#        [0.38560062],
#        [0.38024546],
#        [0.37465229],
#        [0.37746376],
#        [0.37474154],
#        [0.38552622],
#        [0.38281893],
#        [0.39187805],
#        [0.3883377 ],
#        [0.39137229],
#        [0.3881592 ],
#        [0.39021196],
#        [0.39042024],
#        [0.38995911],
#        [0.3957754 ],
#        [0.39799182],
#        [0.40063965],
#        [0.39647455],
#        [0.41013017],
#        [0.41304574],
#        [0.42870956],
#        [0.44187431],
#        [0.41667534],
#        [0.42098921],
#        [0.42722202],
#        [0.44074377],
#        [0.44001488],
#        [0.44022316],
#        [0.43723319],
#        [0.45084419],
#        [0.46223876],
#        [0.45261436],
#        [0.45972481],
#        [0.44304948],
#        [0.45517294],
#        [0.4596653 ],
#        [0.45863889],
#        [0.45863889],
#        [0.47312758],
#        [0.47140203],
#        [0.48431388],
#        [0.48675347],
#        [0.4877501 ],
#        [0.48511716],
#        [0.49451844],
#        [0.49849015],
#        [0.49133508],
#        [0.49017479],
#        [0.50225363],
#        [0.49417629],
#        [0.4957977 ],
#        [0.46945335],
#        [0.46808479],
#        [0.48114541],
#        [0.47187805],
#        [0.48251397],
#        [0.48935666],
#        [0.54927485],
#        [0.56520641],
#        [0.56953517],
#        [0.57190035],
#        [0.59474897],
#        [0.57814805],
#        [0.58775755],
#        [0.56780961],
#        [0.58943848],
#        [0.60133882],
#        [0.60072892],
#        [0.59894385],
#        [0.60462627],
#        [0.60548903],
#        [0.62076611],
#        [0.65703239],
#        [0.66588324],
#        [0.65973968],
#        [0.6698401 ],
#        [0.66084049],
#        [0.65963559],
#        [0.68481961],
#        [0.71540348],
#        [0.69886202],
#        [0.63626627],
#        [0.6367423 ],
#        [0.58830794],
#        [0.61508369],
#        [0.59229454],
#        [0.5834288 ],
#        [0.60342137],
#        [0.6044924 ],
#        [0.58420231],
#        [0.5735515 ],
#        [0.55272591],
#        [0.57200449],
#        [0.58229826],
#        [0.554392  ],
#        [0.56093717],
#        [0.58509484],
#        [0.60104129],
#        [0.59586463],
#        [0.60609893],
#        [0.61193011],
#        [0.58949795],
#        [0.61020456],
#        [0.59033102],
#        [0.60175533],
#        [0.6011008 ],
#        [0.61300114],
#        [0.65721089],
#        [0.63757531],
#        [0.63811085],
#        [0.63525475],
#        [0.62519896],
#        [0.60711049],
#        [0.61621424],
#        [0.61240613],
#        [0.60574193],
#        [0.60151732],
#        [0.60157683],
#        [0.61079956],
#        [0.57866865],
#        [0.60318336],
#        [0.56474528],
#        [0.56420974],
#        [0.57414655],
#        [0.60098178],
#        [0.62525847],
#        [0.62323543],
#        [0.60913353],
#        [0.60705097],
#        [0.62799554],
#        [0.6263295 ],
#        [0.62662703],
#        [0.63281521],
#        [0.62740053],
#        [0.61930831],
#        [0.62293791],
#        [0.61520267],
#        [0.5944366 ],
#        [0.60229082],
#        [0.60740797],
#        [0.61074005],
#        [0.6253775 ],
#        [0.6472146 ],
#        [0.64935667],
#        [0.64852365],
#        [0.64441802],
#        [0.65334327],
#        [0.65709186],
#        [0.64162143],
#        [0.65030867],
#        [0.64537007],
#        [0.64162143],
#        [0.67791744],
#        [0.67750094],
#        [0.68279658],
#        [0.67065828],
#        [0.68      ],
#        [0.70171816],
#        [0.69624402],
#        [0.70225365],
#        [0.73033845],
#        [0.7195091 ],
#        [0.71266645],
#        [0.70653778],
#        [0.68702124],
#        [0.69654146],
#        [0.67030124],
#        [0.69600596],
#        [0.70272968],
#        [0.68446262],
#        [0.68339163],
#        [0.69582746],
#        [0.68404616],
#        [0.67351433],
#        [0.67761997],
#        [0.70261065],
#        [0.73140944],
#        [0.74449988],
#        [0.76740797],
#        [0.76883605],
#        [0.76229083],
#        [0.73271848],
#        [0.70219419],
#        [0.7151655 ],
#        [0.72022318],
#        [0.71397549],
#        [0.73450355],
#        [0.73075492],
#        [0.7316475 ],
#        [0.72629229],
#        [0.72260321],
#        [0.72105621],
#        [0.72248419],
#        [0.70951286],
#        [0.69552993],
#        [0.68880631],
#        [0.68975827],
#        [0.66673115],
#        [0.66589813],
#        [0.66286353],
#        [0.6369208 ],
#        [0.63852736],
#        [0.67738195],
#        [0.66149502],
#        [0.64328747],
#        [0.63180365],
#        [0.63947937],
#        [0.60937154],
#        [0.6375158 ],
#        [0.63091116],
#        [0.64269246],
#        [0.63715881],
#        [0.6547713 ],
#        [0.66417257],
#        [0.65935295],
#        [0.63418372],
#        [0.63097063],
#        [0.6512012 ],
#        [0.64614357],
#        [0.63156563],
#        [0.63454072],
#        [0.63822984],
#        [0.63930087],
#        [0.63043514],
#        [0.64382301],
#        [0.64888064],
#        [0.66613614],
#        [0.66798068],
#        [0.67803648],
#        [0.69267388],
#        [0.70838232],
#        [0.69791005],
#        [0.71689102],
#        [0.70261065],
#        [0.71730757],
#        [0.71528454],
#        [0.7193306 ],
#        [0.70903684],
#        [0.7113574 ],
#        [0.70207515],
#        [0.71623658],
#        [0.71861661],
#        [0.71665305],
#        [0.71183343],
#        [0.71123838],
#        [0.6992191 ],
#        [0.7056452 ],
#        [0.67773894],
#        [0.67922653],
#        [0.6889848 ],
#        [0.69178139],
#        [0.67178878],
#        [0.66619566],
#        [0.64751209],
#        [0.66060248],
#        [0.67535887],
#        [0.66833767],
#        [0.65988844],
#        [0.65893644],
#        [0.67452585],
#        [0.66333955],
#        [0.67327632],
#        [0.67208631],
#        [0.67178878],
#        [0.66244702],
#        [0.65846042],
#        [0.65649685],
#        [0.66113798],
#        [0.65209374],
#        [0.66607662],
#        [0.66613614],
#        [0.67113426],
#        [0.67345482],
#        [0.66738567],
#        [0.67476386],
#        [0.69338787],
#        [0.68838975],
#        [0.69142431],
#        [0.70118257],
#        [0.69326894],
#        [0.70421722],
#        [0.71421346],
#        [0.71254742],
#        [0.71082191],
#        [0.70903684],
#        [0.71897361],
#        [0.72819639],
#        [0.73194502],
#        [0.73378956],
#        [0.74979553],
#        [0.76205285],
#        [0.7772258 ],
#        [0.76931206],
#        [0.78043885],
#        [0.77680925],
#        [0.78359243],
#        [0.80447749],
#        [0.80049089],
#        [0.78805506],
#        [0.76461138],
#        [0.78662699],
#        [0.78216436],
#        [0.79049465],
#        [0.80096691],
#        [0.80352553],
#        [0.79031615],
#        [0.7796653 ],
#        [0.78359243],
#        [0.78490148],
#        [0.78287844],
#        [0.79382673],
#        [0.79138714],
#        [0.79204166],
#        [0.78656751],
#        [0.78626999],
#        [0.78335447],
#        [0.78490148],
#        [0.80293048],
#        [0.80418005],
#        [0.81619933],
#        [0.81066571],
#        [0.78787656],
#        [0.7898996 ],
#        [0.79876538],
#        [0.80780966],
#        [0.80727407],
#        [0.7997769 ],
#        [0.79489771],
#        [0.80120497],
#        [0.82809966],
#        [0.82042399],
#        [0.82447006],
#        [0.83125324],
#        [0.83512091],
#        [0.8493418 ],
#        [0.83994053],
#        [0.83375239],
#        [0.8034065 ],
#        [0.80685761],
#        [0.79834882],
#        [0.8037635 ],
#        [0.80233542],
#        [0.7860915 ],
#        [0.767527  ],
#        [0.77044252],
#        [0.78484201],
#        [0.79067315],
#        [0.79120864],
#        [0.78198586],
#        [0.76139834],
#        [0.76687248],
#        [0.75895874],
#        [0.7658014 ],
#        [0.74491634],
#        [0.75663818],
#        [0.76193383],
#        [0.7696095 ],
#        [0.76728894],
#        [0.76675345],
#        [0.75901822],
#        [0.75544817],
#        [0.77240609],
#        [0.77883228],
#        [0.78900711],
#        [0.80215693],
#        [0.80513201],
#        [0.80644106],
#        [0.80174046],
#        [0.80144293],
#        [0.80548909],
#        [0.80269251],
#        [0.82482714],
#        [0.80834515],
#        [0.80334703],
#        [0.80965419],
#        [0.81840095],
#        [0.81524737],
#        [0.81715138],
#        [0.81215325],
#        [0.81435479],
#        [0.79715881],
#        [0.79686128],
#        [0.8094757 ],
#        [0.80953517],
#        [0.81548533],
#        [0.83030128],
#        [0.85636296],
#        [0.87230945],
#        [0.87510604],
#        [0.8774266 ],
#        [0.88058018],
#        [0.8500558 ],
#        [0.87046491],
#        [0.90057275],
#        [0.89741917],
#        [0.89140944],
#        [0.87998513],
#        [0.90069178],
#        [0.93555967],
#        [0.95876538],
#        [0.95567127],
#        [0.98476758],
#        [0.96269251],
#        [0.95430276],
#        [0.98387509],
#        [0.94198587],
#        [0.9353217 ],
#        [0.92705098],
#        [0.94632955],
#        [0.96209746],
#        [0.96590556],
#        [0.99000376],
#        [0.98381553],
#        [0.98435112],
#        [0.97732987],
#        [0.97358133],
#        [1.        ],
#        [0.98625512],
#        [0.95781333],
#        [0.94043885],
#        [0.94145037],
#        [0.9415694 ],
#        [0.95876538],
#        [0.96144294],
#        [0.9415694 ],
#        [0.94680557],
#        [0.9273485 ],
#        [0.90610636],
#        [0.89587207],
#        [0.88337677],
#        [0.87867608],
#        [0.8677278 ],
#        [0.8671923 ],
#        [0.86439572],
#        [0.93050208],
#        [0.95698031],
#        [0.9559688 ],
#        [0.96328747],
#        [0.94579397],
#        [0.94275941],
#        [0.93841582],
#        [0.95727784],
#        [0.96590556],
#        [0.94115284],
#        [0.92044628],
#        [0.92187436],
#        [0.94513944],
#        [0.94371146],
#        [0.92187436],
#        [0.91247308],
#        [0.89474161],
#        [0.8694534 ],
#        [0.88534033],
#        [0.89789519],
#        [0.89950167],
#        [0.88807736],
#        [0.90806993],
#        [0.90610636],
#        [0.88789886],
#        [0.86487174],
#        [0.85380443],
#        [0.88658982],
#        [0.86023062],
#        [0.83767944],
#        [0.81322424],
#        [0.8398215 ],
#        [0.86659725],
#        [0.87272592],
#        [0.89271849],
#        [0.90104877],
#        [0.92151736],
#        [0.92978809],
#        [0.95275574],
#        [0.95662331],
#        [0.96185949],
#        [0.98185206],
#        [0.97477134],
#        [0.9559688 ],
#        [0.95418373],
#        [0.97875794],
#        [0.95864635],
#        [0.93942734],
#        [0.94127187],
#        [0.92907401],
#        [0.90325031],
#        [0.91461515],
#        [0.93091855],
#        [0.90051319],
#        [0.89920423],
#        [0.91306805],
#        [0.91205653],
#        [0.90723691],
#        [0.8796876 ],
#        [0.88617335],
#        [0.84999632],
#        [0.84862781],
#        [0.89069545],
#        [0.85505391],
#        [0.85689854],
#        [0.86594273],
#        [0.90485687],
#        [0.84981783],
#        [0.85285238],
#        [0.8217925 ],
#        [0.83637039],
#        [0.78870958],
#        [0.76526591],
#        [0.79233919],
#        [0.78299738],
#        [0.80501307],
#        [0.75491267],
#        [0.73426558],
#        [0.73569356],
#        [0.76853852],
#        [0.75217556],
#        [0.7531276 ],
#        [0.77252512],
#        [0.8073931 ],
#        [0.80263295],
#        [0.80185949],
#        [0.81673491],
#        [0.78204542],
#        [0.78656751],
#        [0.80185949],
#        [0.79739687],
#        [0.76574193],
#        [0.73295654],
#        [0.70171816],
#        [0.70695425],
#        [0.72284118],
#        [0.69088881],
#        [0.69981407],
#        [0.72545927],
#        [0.72236525],
#        [0.73973973],
#        [0.75991079],
#        [0.75991079],
#        [0.73480108],
#        [0.74545184],
#        [0.73051695],
#        [0.74366677],
#        [0.75931574],
#        [0.76740797],
#        [0.78781709],
#        [0.79192263],
#        [0.77901078],
#        [0.78490148],
#        [0.78269994],
#        [0.80043142],
#        [0.81054668],
#        [0.79210122],
#        [0.81548533],
#        [0.82762363],
#        [0.8413686 ],
#        [0.83387133],
#        [0.82708814],
#        [0.81905547],
#        [0.84993676],
#        [0.85326893],
#        [0.88397173],
#        [0.87802157],
#        [0.86909631],
#        [0.9055114 ],
#        [0.9036073 ],
#        [0.90087027],
#        [0.89801413],
#        [0.89831165],
#        [0.92401642],
#        [0.91955379],
#        [0.94103391],
#        [0.94751956],
#        [0.94656752],
#        [0.9556118 ],
#        [0.95323168],
#        [0.9375828 ],
#        [0.91407965],
#        [0.91205653],
#        [0.9138416 ],
#        [0.92871702],
#        [0.89057642],
#        [0.8772481 ],
#        [0.86255118],
#        [0.85249538],
#        [0.85689854],
#        [0.84410563],
#        [0.83648942],
#        [0.84499821],
#        [0.83607296],
#        [0.85338787],
#        [0.88944588],
#        [0.83238379],
#        [0.84113054],
#        [0.82363703],
#        [0.81370027],
#        [0.83619189],
#        [0.85059129],
#        [0.8316698 ],
#        [0.82583866],
#        [0.8120937 ],
#        [0.81411682],
#        [0.82000743],
#        [0.80858312],
#        [0.76478988],
#        [0.73932317],
#        [0.76461138],
#        [0.78632955],
#        [0.78811453],
#        [0.78234286],
#        [0.75056898],
#        [0.75253255],
#        [0.7439643 ],
#        [0.74015619],
#        [0.76782452],
#        [0.74039425],
#        [0.76437342],
#        [0.77234662],
#        [0.77300114],
#        [0.77020455],
#        [0.79329123],
#        [0.80626256],
#        [0.82345854],
#        [0.80566759],
#        [0.77859431],
#        [0.84368916],
#        [0.8294087 ],
#        [0.81340274],
#        [0.77996283],
#        [0.74336933],
#        [0.74039425],
#        [0.7436073 ],
#        [0.74705841],
#        [0.7195091 ],
#        [0.79091111],
#        [0.8077501 ],
#        [0.79930087],
#        [0.80977313],
#        [0.80233542],
#        [0.81381929],
#        [0.81721084],
#        [0.7976943 ],
#        [0.81060616],
#        [0.81590189],
#        [0.79828936],
#        [0.7751432 ],
#        [0.75699518],
#        [0.79781333],
#        [0.79947937],
#        [0.79650429],
#        [0.78948313],
#        [0.7673485 ],
#        [0.75562666],
#        [0.7658014 ],
#        [0.76288588],
#        [0.77674977],
#        [0.78258091],
#        [0.76913357],
#        [0.72920791],
#        [0.71736704],
#        [0.70463368],
#        [0.70421722],
#        [0.72296021],
#        [0.70380067],
#        [0.70159913],
#        [0.69071032],
#        [0.66696916],
#        [0.68821126],
#        [0.69011526],
#        [0.66119749],
#        [0.66887321],
#        [0.66089996],
#        [0.68827072],
#        [0.69142431],
#        [0.69487542],
#        [0.71129793],
#        [0.71082191],
#        [0.71885458],
#        [0.72587582],
#        [0.72153223],
#        [0.72188922],
#        [0.73735961],
#        [0.75663818],
#        [0.76508741],
#        [0.76110081],
#        [0.7735962 ],
#        [0.78531794],
#        [0.76788399],
#        [0.77555967],
#        [0.78234286],
#        [0.81441435],
#        [0.83631092],
#        [0.81982893],
#        [0.83720341],
#        [0.82095948],
#        [0.81471178],
#        [0.81554481],
#        [0.83244335],
#        [0.82857569],
#        [0.84124957],
#        [0.83161033],
#        [0.82470811],
#        [0.80049089],
#        [0.80304951],
#        [0.80596503],
#        [0.78995916],
#        [0.79715881],
#        [0.79412426],
#        [0.78162887],
#        [0.78519901],
#        [0.81566383],
#        [0.83232432],
#        [0.81905547],
#        [0.82661212],
#        [0.81304574],
#        [0.80060992],
#        [0.81233175],
#        [0.82494608],
#        [0.8273262 ],
#        [0.84434368],
#        [0.839286  ],
#        [0.85356637],
#        [0.86475272],
#        [0.85612499],
#        [0.86267012],
#        [0.87052438],
#        [0.85880255],
#        [0.85505391],
#        [0.8736185 ],
#        [0.88307924],
#        [0.89819263],
#        [0.90574936],
#        [0.90253632],
#        [0.89140944],
#        [0.89676465],
#        [0.88111568],
#        [0.87379699],
#        [0.86963189],
#        [0.90211976],
#        [0.90003726]])

# %%
test_data.shape
# Out:
# (907, 1)

# %%
# Use only last 60 days
i = len(test_data)-LOOK_BACK
x_input = test_data[i:].reshape(1,-1)
x_input
# Out:
# array([[0.72188922, 0.73735961, 0.75663818, 0.76508741, 0.76110081,
#         0.7735962 , 0.78531794, 0.76788399, 0.77555967, 0.78234286,
#         0.81441435, 0.83631092, 0.81982893, 0.83720341, 0.82095948,
#         0.81471178, 0.81554481, 0.83244335, 0.82857569, 0.84124957,
#         0.83161033, 0.82470811, 0.80049089, 0.80304951, 0.80596503,
#         0.78995916, 0.79715881, 0.79412426, 0.78162887, 0.78519901,
#         0.81566383, 0.83232432, 0.81905547, 0.82661212, 0.81304574,
#         0.80060992, 0.81233175, 0.82494608, 0.8273262 , 0.84434368,
#         0.839286  , 0.85356637, 0.86475272, 0.85612499, 0.86267012,
#         0.87052438, 0.85880255, 0.85505391, 0.8736185 , 0.88307924,
#         0.89819263, 0.90574936, 0.90253632, 0.89140944, 0.89676465,
#         0.88111568, 0.87379699, 0.86963189, 0.90211976, 0.90003726]])

# %%
x_input.shape
# Out:
# (1, 60)

# %%
temp_input = list(x_input)
temp_input
# Out:
# [array([0.72188922, 0.73735961, 0.75663818, 0.76508741, 0.76110081,
#         0.7735962 , 0.78531794, 0.76788399, 0.77555967, 0.78234286,
#         0.81441435, 0.83631092, 0.81982893, 0.83720341, 0.82095948,
#         0.81471178, 0.81554481, 0.83244335, 0.82857569, 0.84124957,
#         0.83161033, 0.82470811, 0.80049089, 0.80304951, 0.80596503,
#         0.78995916, 0.79715881, 0.79412426, 0.78162887, 0.78519901,
#         0.81566383, 0.83232432, 0.81905547, 0.82661212, 0.81304574,
#         0.80060992, 0.81233175, 0.82494608, 0.8273262 , 0.84434368,
#         0.839286  , 0.85356637, 0.86475272, 0.85612499, 0.86267012,
#         0.87052438, 0.85880255, 0.85505391, 0.8736185 , 0.88307924,
#         0.89819263, 0.90574936, 0.90253632, 0.89140944, 0.89676465,
#         0.88111568, 0.87379699, 0.86963189, 0.90211976, 0.90003726])]

# %%
temp_input = temp_input[0].tolist()
temp_input
# Out:
# [0.7218892234106128,
#  0.7373596054253507,
#  0.7566381839089085,
#  0.7650874098947537,
#  0.7611008095530177,
#  0.773596197057529,
#  0.7853179437803776,
#  0.7678839945818964,
#  0.7755596690385919,
#  0.782342860017638,
#  0.8144143462823159,
#  0.8363109211249065,
#  0.8198289332786591,
#  0.8372034105527232,
#  0.8209594770088352,
#  0.8147117832565796,
#  0.8155448067101467,
#  0.8324433479343503,
#  0.828575685491281,
#  0.8412495720713893,
#  0.8316103304309506,
#  0.8247081123007247,
#  0.800490888820852,
#  0.8030495084581482,
#  0.8059650310439577,
#  0.7899591577525966,
#  0.7971588069069186,
#  0.7941242571699294,
#  0.7816288696654182,
#  0.7851990058817107,
#  0.8156638338613263,
#  0.8323243207831705,
#  0.8190554710020221,
#  0.8266121183075378,
#  0.813045742299613,
#  0.8006099159720317,
#  0.812331751947393,
#  0.8249460773505713,
#  0.8273261979122706,
#  0.8443436829853085,
#  0.839286004887646,
#  0.8535663712477908,
#  0.8647527159465292,
#  0.8561249908850871,
#  0.8626701216116064,
#  0.8705243843964116,
#  0.8588025484210501,
#  0.8550539131291606,
#  0.8736184953103308,
#  0.8830792438253401,
#  0.8981926276888843,
#  0.9057493642469129,
#  0.902536315434327,
#  0.8914094426600057,
#  0.8967646469844446,
#  0.8811156766415968,
#  0.8737969943859276,
#  0.8696318949685948,
#  0.9021197620563708,
#  0.9000372569739606]

# %%
def predictUpcomingDays(stock_prices,numOfDays=5,look_back=60):
    
    # Use only last 60 days
    i = len(stock_prices)-LOOK_BACK
    x_input = stock_prices[i:].reshape(1,-1)
    temp_input = list(x_input)
    temp_input = temp_input[0].tolist()
    
    lst_output=[]
    n_steps=look_back
    i=0
    while(i<numOfDays):
        if(len(temp_input)>look_back):
            #print(temp_input)
            x_input=np.array(temp_input[1:])
            print("{} day input {}".format(i,x_input))
            x_input=x_input.reshape(1,-1)
            x_input = x_input.reshape((1, n_steps, 1))
            #print(x_input)
            yhat = model.predict(x_input, verbose=0)
            print("{} day output {}".format(i,yhat))
            temp_input.extend(yhat[0].tolist())
            temp_input=temp_input[1:]
            #print(temp_input)
            lst_output.extend(yhat.tolist())
            i=i+1
        else:
            x_input = x_input.reshape((1, n_steps,1))
            yhat = model.predict(x_input, verbose=0)
            print(yhat[0])
            temp_input.extend(yhat[0].tolist())
            print(len(temp_input))
            lst_output.extend(yhat.tolist())
            i=i+1
    
    results = scaler.inverse_transform(lst_output)
    results = results.reshape(1,-1).tolist()[0]
    return results

# %%
results = predictUpcomingDays(test_data)
# Out:
# [0.9322215]
# 61
# 1 day input [0.73735961 0.75663818 0.76508741 0.76110081 0.7735962  0.78531794
#  0.76788399 0.77555967 0.78234286 0.81441435 0.83631092 0.81982893
#  0.83720341 0.82095948 0.81471178 0.81554481 0.83244335 0.82857569
#  0.84124957 0.83161033 0.82470811 0.80049089 0.80304951 0.80596503
#  0.78995916 0.79715881 0.79412426 0.78162887 0.78519901 0.81566383
#  0.83232432 0.81905547 0.82661212 0.81304574 0.80060992 0.81233175
#  0.82494608 0.8273262  0.84434368 0.839286   0.85356637 0.86475272
#  0.85612499 0.86267012 0.87052438 0.85880255 0.85505391 0.8736185
#  0.88307924 0.89819263 0.90574936 0.90253632 0.89140944 0.89676465
#  0.88111568 0.87379699 0.86963189 0.90211976 0.90003726 0.93222147]
# 1 day output [[0.95670325]]
# 2 day input [0.75663818 0.76508741 0.76110081 0.7735962  0.78531794 0.76788399
#  0.77555967 0.78234286 0.81441435 0.83631092 0.81982893 0.83720341
#  0.82095948 0.81471178 0.81554481 0.83244335 0.82857569 0.84124957
#  0.83161033 0.82470811 0.80049089 0.80304951 0.80596503 0.78995916
#  0.79715881 0.79412426 0.78162887 0.78519901 0.81566383 0.83232432
#  0.81905547 0.82661212 0.81304574 0.80060992 0.81233175 0.82494608
#  0.8273262  0.84434368 0.839286   0.85356637 0.86475272 0.85612499
#  0.86267012 0.87052438 0.85880255 0.85505391 0.8736185  0.88307924
#  0.89819263 0.90574936 0.90253632 0.89140944 0.89676465 0.88111568
#  0.87379699 0.86963189 0.90211976 0.90003726 0.93222147 0.95670325]
# 2 day output [[0.98335034]]
# 3 day input [0.76508741 0.76110081 0.7735962  0.78531794 0.76788399 0.77555967
#  0.78234286 0.81441435 0.83631092 0.81982893 0.83720341 0.82095948
#  0.81471178 0.81554481 0.83244335 0.82857569 0.84124957 0.83161033
#  0.82470811 0.80049089 0.80304951 0.80596503 0.78995916 0.79715881
#  0.79412426 0.78162887 0.78519901 0.81566383 0.83232432 0.81905547
#  0.82661212 0.81304574 0.80060992 0.81233175 0.82494608 0.8273262
#  0.84434368 0.839286   0.85356637 0.86475272 0.85612499 0.86267012
#  0.87052438 0.85880255 0.85505391 0.8736185  0.88307924 0.89819263
#  0.90574936 0.90253632 0.89140944 0.89676465 0.88111568 0.87379699
#  0.86963189 0.90211976 0.90003726 0.93222147 0.95670325 0.98335034]
# 3 day output [[1.0096501]]
# 4 day input [0.76110081 0.7735962  0.78531794 0.76788399 0.77555967 0.78234286
#  0.81441435 0.83631092 0.81982893 0.83720341 0.82095948 0.81471178
#  0.81554481 0.83244335 0.82857569 0.84124957 0.83161033 0.82470811
#  0.80049089 0.80304951 0.80596503 0.78995916 0.79715881 0.79412426
#  0.78162887 0.78519901 0.81566383 0.83232432 0.81905547 0.82661212
#  0.81304574 0.80060992 0.81233175 0.82494608 0.8273262  0.84434368
#  0.839286   0.85356637 0.86475272 0.85612499 0.86267012 0.87052438
#  0.85880255 0.85505391 0.8736185  0.88307924 0.89819263 0.90574936
#  0.90253632 0.89140944 0.89676465 0.88111568 0.87379699 0.86963189
#  0.90211976 0.90003726 0.93222147 0.95670325 0.98335034 1.00965011]
# 4 day output [[1.0347631]]

# %%
results = scaler.inverse_transform(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [423], in <cell line: 1>()
# ----> 1 results = scaler.inverse_transform(results)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:537, in MinMaxScaler.inverse_transform(self, X)
#     523 """Undo the scaling of X according to feature_range.
#     524
#     525 Parameters
#    (...)
#     533     Transformed data.
#     534 """
#     535 check_is_fitted(self)
# --> 537 X = check_array(
#     538     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     539 )
#     541 X -= self.min_
#     542 X /= self.scale_
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:902, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900     # If input is 1D raise error
#     901     if array.ndim == 1:
# --> 902         raise ValueError(
#     903             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904             "Reshape your data either using array.reshape(-1, 1) if "
#     905             "your data has a single feature or array.reshape(1, -1) "
#     906             "if it contains a single sample.".format(array)
#     907         )
#     909 if dtype_numeric and array.dtype.kind in "USV":
#     910     raise ValueError(
#     911         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     912         "Convert your data to numeric values explicitly instead."
#     913     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[170.61896652 174.73343444 179.21181102 183.63181677 187.85236794].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
results = results.reshape(1,-1).tolist()[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [424], in <cell line: 1>()
# ----> 1 results = results.reshape(1,-1).tolist()[0]
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
results
# Out:
# [170.6189665211496,
#  174.73343443682285,
#  179.21181101996274,
#  183.6318167650348,
#  187.85236794398904]

# %% [markdown]
# # 7. Saving Model

# %%
import joblib
model.save('AAPL')
joblib.dump(scaler, 'scaler.gz')
scaler = joblib.load('scaler.gz')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses, lstm_cell_43_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: AAPL/assets
# INFO:tensorflow:Assets written to: AAPL/assets

# %%
model = None
model = tf.keras.models.load_model('AAPL')
results = predictUpcomingDays(test_data)
results
# Out:
# [0.9322215]
# 61
# 1 day input [0.73735961 0.75663818 0.76508741 0.76110081 0.7735962  0.78531794
#  0.76788399 0.77555967 0.78234286 0.81441435 0.83631092 0.81982893
#  0.83720341 0.82095948 0.81471178 0.81554481 0.83244335 0.82857569
#  0.84124957 0.83161033 0.82470811 0.80049089 0.80304951 0.80596503
#  0.78995916 0.79715881 0.79412426 0.78162887 0.78519901 0.81566383
#  0.83232432 0.81905547 0.82661212 0.81304574 0.80060992 0.81233175
#  0.82494608 0.8273262  0.84434368 0.839286   0.85356637 0.86475272
#  0.85612499 0.86267012 0.87052438 0.85880255 0.85505391 0.8736185
#  0.88307924 0.89819263 0.90574936 0.90253632 0.89140944 0.89676465
#  0.88111568 0.87379699 0.86963189 0.90211976 0.90003726 0.93222147]
# 1 day output [[0.95670325]]
# 2 day input [0.75663818 0.76508741 0.76110081 0.7735962  0.78531794 0.76788399
#  0.77555967 0.78234286 0.81441435 0.83631092 0.81982893 0.83720341
#  0.82095948 0.81471178 0.81554481 0.83244335 0.82857569 0.84124957
#  0.83161033 0.82470811 0.80049089 0.80304951 0.80596503 0.78995916
#  0.79715881 0.79412426 0.78162887 0.78519901 0.81566383 0.83232432
#  0.81905547 0.82661212 0.81304574 0.80060992 0.81233175 0.82494608
#  0.8273262  0.84434368 0.839286   0.85356637 0.86475272 0.85612499
#  0.86267012 0.87052438 0.85880255 0.85505391 0.8736185  0.88307924
#  0.89819263 0.90574936 0.90253632 0.89140944 0.89676465 0.88111568
#  0.87379699 0.86963189 0.90211976 0.90003726 0.93222147 0.95670325]
# 2 day output [[0.98335034]]
# 3 day input [0.76508741 0.76110081 0.7735962  0.78531794 0.76788399 0.77555967
#  0.78234286 0.81441435 0.83631092 0.81982893 0.83720341 0.82095948
#  0.81471178 0.81554481 0.83244335 0.82857569 0.84124957 0.83161033
#  0.82470811 0.80049089 0.80304951 0.80596503 0.78995916 0.79715881
#  0.79412426 0.78162887 0.78519901 0.81566383 0.83232432 0.81905547
#  0.82661212 0.81304574 0.80060992 0.81233175 0.82494608 0.8273262
#  0.84434368 0.839286   0.85356637 0.86475272 0.85612499 0.86267012
#  0.87052438 0.85880255 0.85505391 0.8736185  0.88307924 0.89819263
#  0.90574936 0.90253632 0.89140944 0.89676465 0.88111568 0.87379699
#  0.86963189 0.90211976 0.90003726 0.93222147 0.95670325 0.98335034]
# 3 day output [[1.0096501]]
# 4 day input [0.76110081 0.7735962  0.78531794 0.76788399 0.77555967 0.78234286
#  0.81441435 0.83631092 0.81982893 0.83720341 0.82095948 0.81471178
#  0.81554481 0.83244335 0.82857569 0.84124957 0.83161033 0.82470811
#  0.80049089 0.80304951 0.80596503 0.78995916 0.79715881 0.79412426
#  0.78162887 0.78519901 0.81566383 0.83232432 0.81905547 0.82661212
#  0.81304574 0.80060992 0.81233175 0.82494608 0.8273262  0.84434368
#  0.839286   0.85356637 0.86475272 0.85612499 0.86267012 0.87052438
#  0.85880255 0.85505391 0.8736185  0.88307924 0.89819263 0.90574936
#  0.90253632 0.89140944 0.89676465 0.88111568 0.87379699 0.86963189
#  0.90211976 0.90003726 0.93222147 0.95670325 0.98335034 1.00965011]
# 4 day output [[1.0347631]]
# [170.6189665211496,
#  174.73343443682285,
#  179.21181101996274,
#  183.6318167650348,
#  187.85236794398904]

# %%
# 8. Sav

# %%
train_predict
# Out:
# array([[15.844549],
#        [15.563638],
#        [15.281086],
#        ...,
#        [50.82967 ],
#        [51.034138],
#        [51.175835]], dtype=float32)

# %%
test_predict
# Out:
# array([[ 64.98842 ],
#        [ 64.16564 ],
#        [ 63.460407],
#        [ 63.476196],
#        [ 64.34745 ],
#        [ 65.0206  ],
#        [ 65.346146],
#        [ 65.55502 ],
#        [ 65.709854],
#        [ 66.09696 ],
#        [ 66.899124],
#        [ 67.68884 ],
#        [ 68.07639 ],
#        [ 68.106064],
#        [ 67.91141 ],
#        [ 68.101814],
#        [ 68.52298 ],
#        [ 69.391525],
#        [ 70.190186],
#        [ 70.75259 ],
#        [ 71.16066 ],
#        [ 71.94761 ],
#        [ 72.4238  ],
#        [ 72.69116 ],
#        [ 72.64176 ],
#        [ 72.87904 ],
#        [ 73.82974 ],
#        [ 74.88603 ],
#        [ 76.12789 ],
#        [ 76.59781 ],
#        [ 76.26609 ],
#        [ 76.02718 ],
#        [ 76.35071 ],
#        [ 76.67249 ],
#        [ 76.911835],
#        [ 77.15934 ],
#        [ 77.239296],
#        [ 76.30823 ],
#        [ 75.96441 ],
#        [ 76.835304],
#        [ 77.96072 ],
#        [ 77.29208 ],
#        [ 75.69771 ],
#        [ 75.32005 ],
#        [ 76.14053 ],
#        [ 77.5444  ],
#        [ 78.10806 ],
#        [ 78.009445],
#        [ 77.45181 ],
#        [ 77.608116],
#        [ 77.943756],
#        [ 78.17178 ],
#        [ 77.671585],
#        [ 77.39622 ],
#        [ 77.14317 ],
#        [ 76.301994],
#        [ 74.07034 ],
#        [ 71.0515  ],
#        [ 69.325   ],
#        [ 67.392876],
#        [ 65.894646],
#        [ 67.48541 ],
#        [ 69.42302 ],
#        [ 71.608116],
#        [ 72.12072 ],
#        [ 70.95268 ],
#        [ 67.30951 ],
#        [ 65.40726 ],
#        [ 64.69072 ],
#        [ 62.399963],
#        [ 62.463905],
#        [ 61.118576],
#        [ 60.015404],
#        [ 59.116985],
#        [ 58.44956 ],
#        [ 56.814686],
#        [ 54.68488 ],
#        [ 54.89989 ],
#        [ 56.45343 ],
#        [ 59.0582  ],
#        [ 60.374405],
#        [ 60.853645],
#        [ 60.773113],
#        [ 59.37843 ],
#        [ 58.071342],
#        [ 57.205887],
#        [ 58.696697],
#        [ 60.936745],
#        [ 63.183865],
#        [ 64.773056],
#        [ 65.867256],
#        [ 67.554016],
#        [ 68.87011 ],
#        [ 69.61405 ],
#        [ 69.46998 ],
#        [ 68.42565 ],
#        [ 66.62001 ],
#        [ 65.83591 ],
#        [ 66.01259 ],
#        [ 67.31329 ],
#        [ 68.75906 ],
#        [ 69.22072 ],
#        [ 69.66449 ],
#        [ 70.55753 ],
#        [ 70.93183 ],
#        [ 71.1132  ],
#        [ 71.544136],
#        [ 72.25435 ],
#        [ 73.11628 ],
#        [ 74.29813 ],
#        [ 75.6648  ],
#        [ 76.258995],
#        [ 75.79212 ],
#        [ 75.1383  ],
#        [ 74.590706],
#        [ 75.01815 ],
#        [ 75.70139 ],
#        [ 76.73296 ],
#        [ 77.32422 ],
#        [ 77.554   ],
#        [ 77.302826],
#        [ 77.00334 ],
#        [ 76.8368  ],
#        [ 76.77365 ],
#        [ 77.13815 ],
#        [ 77.73655 ],
#        [ 78.34786 ],
#        [ 78.42234 ],
#        [ 78.99686 ],
#        [ 79.87131 ],
#        [ 81.50137 ],
#        [ 83.73064 ],
#        [ 83.674095],
#        [ 82.49609 ],
#        [ 81.808304],
#        [ 82.70389 ],
#        [ 84.08459 ],
#        [ 85.05763 ],
#        [ 85.17618 ],
#        [ 85.706856],
#        [ 87.10737 ],
#        [ 87.73124 ],
#        [ 88.01644 ],
#        [ 86.95648 ],
#        [ 86.41528 ],
#        [ 86.86    ],
#        [ 87.577324],
#        [ 88.06716 ],
#        [ 89.18378 ],
#        [ 90.09359 ],
#        [ 91.28858 ],
#        [ 92.30234 ],
#        [ 92.788376],
#        [ 92.584785],
#        [ 92.77766 ],
#        [ 93.473236],
#        [ 93.64237 ],
#        [ 93.34968 ],
#        [ 93.86167 ],
#        [ 94.12314 ],
#        [ 94.18572 ],
#        [ 92.3317  ],
#        [ 90.15997 ],
#        [ 89.86767 ],
#        [ 90.16812 ],
#        [ 91.219734],
#        [ 92.649376],
#        [ 97.731125],
#        [103.6879  ],
#        [107.319336],
#        [107.98364 ],
#        [108.4826  ],
#        [107.67587 ],
#        [107.29727 ],
#        [106.14192 ],
#        [106.912994],
#        [109.60119 ],
#        [112.06787 ],
#        [113.098885],
#        [113.39202 ],
#        [113.35151 ],
#        [114.36719 ],
#        [118.28382 ],
#        [122.47988 ],
#        [124.073845],
#        [124.27834 ],
#        [123.153946],
#        [121.9327  ],
#        [123.493614],
#        [128.38245 ],
#        [131.20557 ],
#        [126.40781 ],
#        [120.345474],
#        [113.529755],
#        [112.05019 ],
#        [112.58043 ],
#        [112.947815],
#        [114.472534],
#        [115.85259 ],
#        [114.58358 ],
#        [111.4218  ],
#        [107.15613 ],
#        [105.746994],
#        [107.30691 ],
#        [107.3434  ],
#        [106.74289 ],
#        [107.97711 ],
#        [110.79177 ],
#        [112.47869 ],
#        [113.291885],
#        [113.707115],
#        [112.02121 ],
#        [111.609   ],
#        [110.81518 ],
#        [111.05721 ],
#        [111.86224 ],
#        [113.5164  ],
#        [118.26337 ],
#        [120.81302 ],
#        [120.696045],
#        [119.13324 ],
#        [116.96002 ],
#        [114.26658 ],
#        [113.48663 ],
#        [114.021286],
#        [114.47831 ],
#        [114.349846],
#        [114.01782 ],
#        [114.45877 ],
#        [112.57953 ],
#        [112.085205],
#        [109.777405],
#        [107.38477 ],
#        [106.97047 ],
#        [109.823395],
#        [114.72424 ],
#        [117.88353 ],
#        [117.219864],
#        [114.668846],
#        [114.15033 ],
#        [114.97514 ],
#        [116.03867 ],
#        [117.21736 ],
#        [117.57713 ],
#        [116.785545],
#        [116.18975 ],
#        [115.54423 ],
#        [113.622795],
#        [112.62803 ],
#        [113.163284],
#        [114.45762 ],
#        [116.525345],
#        [119.58401 ],
#        [121.694115],
#        [122.00494 ],
#        [120.86084 ],
#        [120.29124 ],
#        [120.735176],
#        [120.319496],
#        [120.40059 ],
#        [120.53534 ],
#        [120.41619 ],
#        [123.184555],
#        [126.141304],
#        [127.91735 ],
#        [127.1832  ],
#        [126.291306],
#        [127.682175],
#        [129.16176 ],
#        [130.32916 ],
#        [133.12689 ],
#        [134.57518 ],
#        [133.9713  ],
#        [132.28452 ],
#        [129.53194 ],
#        [128.61809 ],
#        [127.21608 ],
#        [128.39957 ],
#        [131.02611 ],
#        [131.4037  ],
#        [130.19208 ],
#        [129.85599 ],
#        [129.18184 ],
#        [127.66705 ],
#        [126.813324],
#        [128.82375 ],
#        [133.59708 ],
#        [138.20769 ],
#        [142.01343 ],
#        [143.5195  ],
#        [142.50294 ],
#        [138.37668 ],
#        [132.49788 ],
#        [130.32077 ],
#        [132.06421 ],
#        [134.4652  ],
#        [137.63644 ],
#        [139.27106 ],
#        [139.19368 ],
#        [137.76381 ],
#        [136.00568 ],
#        [134.83446 ],
#        [134.68282 ],
#        [134.05519 ],
#        [132.35077 ],
#        [130.52135 ],
#        [129.76491 ],
#        [128.0871  ],
#        [126.63959 ],
#        [125.83902 ],
#        [123.60103 ],
#        [121.73421 ],
#        [124.107704],
#        [126.06887 ],
#        [124.891754],
#        [121.63107 ],
#        [119.59736 ],
#        [116.89595 ],
#        [117.246475],
#        [118.583595],
#        [120.451126],
#        [121.1313  ],
#        [122.095924],
#        [123.455154],
#        [123.82818 ],
#        [121.39999 ],
#        [118.500145],
#        [118.64591 ],
#        [120.05003 ],
#        [120.13645 ],
#        [119.71457 ],
#        [119.66734 ],
#        [119.94845 ],
#        [119.50255 ],
#        [119.87865 ],
#        [120.923935],
#        [123.05727 ],
#        [124.764656],
#        [126.06921 ],
#        [127.67868 ],
#        [129.9119  ],
#        [130.49095 ],
#        [131.44417 ],
#        [131.16228 ],
#        [131.66055 ],
#        [132.39183 ],
#        [133.30598 ],
#        [133.14833 ],
#        [132.83537 ],
#        [132.03107 ],
#        [132.65059 ],
#        [133.99013 ],
#        [134.79059 ],
#        [134.47514 ],
#        [133.73004 ],
#        [132.21657 ],
#        [131.63765 ],
#        [129.62294 ],
#        [127.992546],
#        [128.34349 ],
#        [129.75246 ],
#        [129.20001 ],
#        [127.33098 ],
#        [124.28578 ],
#        [123.225586],
#        [124.943275],
#        [126.47278 ],
#        [126.187   ],
#        [124.955   ],
#        [125.12595 ],
#        [125.022575],
#        [125.45146 ],
#        [125.85022 ],
#        [125.95494 ],
#        [125.10576 ],
#        [123.89379 ],
#        [123.03661 ],
#        [123.22456 ],
#        [123.153114],
#        [124.04236 ],
#        [125.01995 ],
#        [125.844795],
#        [126.305885],
#        [125.812035],
#        [125.636055],
#        [127.26492 ],
#        [128.59526 ],
#        [129.22958 ],
#        [130.02942 ],
#        [129.94879 ],
#        [130.36049 ],
#        [131.75609 ],
#        [132.8417  ],
#        [133.07079 ],
#        [132.68666 ],
#        [133.12253 ],
#        [134.62564 ],
#        [136.22198 ],
#        [137.18422 ],
#        [138.69371 ],
#        [140.79866 ],
#        [143.37007 ],
#        [144.17674 ],
#        [144.6193  ],
#        [144.5302  ],
#        [144.91443 ],
#        [147.2947  ],
#        [149.21678 ],
#        [148.86307 ],
#        [145.7238  ],
#        [144.99872 ],
#        [145.78778 ],
#        [147.59964 ],
#        [149.88225 ],
#        [151.3924  ],
#        [150.53787 ],
#        [148.04048 ],
#        [146.49356 ],
#        [146.46982 ],
#        [147.04854 ],
#        [148.5512  ],
#        [149.52278 ],
#        [149.71059 ],
#        [148.93484 ],
#        [148.06068 ],
#        [147.37863 ],
#        [147.29402 ],
#        [149.11913 ],
#        [151.02306 ],
#        [152.87512 ],
#        [153.22417 ],
#        [150.64641 ],
#        [148.22774 ],
#        [148.15791 ],
#        [150.1502  ],
#        [152.0209  ],
#        [152.14508 ],
#        [150.94939 ],
#        [150.36128 ],
#        [152.7629  ],
#        [154.64432 ],
#        [155.43442 ],
#        [155.89279 ],
#        [156.33144 ],
#        [157.78694 ],
#        [158.18687 ],
#        [157.32632 ],
#        [153.81708 ],
#        [151.3803  ],
#        [150.34901 ],
#        [151.12523 ],
#        [152.28914 ],
#        [151.53838 ],
#        [148.56732 ],
#        [146.33899 ],
#        [146.91675 ],
#        [148.91695 ],
#        [150.3215  ],
#        [149.68927 ],
#        [146.51332 ],
#        [144.20961 ],
#        [142.97426 ],
#        [143.4466  ],
#        [142.71524 ],
#        [142.67091 ],
#        [143.50502 ],
#        [144.86696 ],
#        [145.42238 ],
#        [145.08772 ],
#        [143.7718  ],
#        [142.32782 ],
#        [143.0543  ],
#        [145.06345 ],
#        [147.41376 ],
#        [149.75867 ],
#        [151.0877  ],
#        [151.28821 ],
#        [150.45981 ],
#        [149.62103 ],
#        [149.72064 ],
#        [150.13293 ],
#        [152.49835 ],
#        [153.26633 ],
#        [152.37411 ],
#        [151.8392  ],
#        [152.65189 ],
#        [153.42796 ],
#        [153.89516 ],
#        [153.56673 ],
#        [153.24911 ],
#        [151.67834 ],
#        [150.3271  ],
#        [151.02623 ],
#        [152.39525 ],
#        [153.77551 ],
#        [155.65926 ],
#        [158.9875  ],
#        [162.51624 ],
#        [164.34549 ],
#        [164.51962 ],
#        [164.16249 ],
#        [161.2083  ],
#        [160.57791 ],
#        [164.50705 ],
#        [168.34769 ],
#        [169.514   ],
#        [167.91505 ],
#        [167.89435 ],
#        [171.93307 ],
#        [177.73141 ],
#        [180.81326 ],
#        [183.54276 ],
#        [182.8581  ],
#        [180.2437  ],
#        [181.12308 ],
#        [179.67865 ],
#        [177.48726 ],
#        [175.8708  ],
#        [177.51392 ],
#        [181.38078 ],
#        [184.4156  ],
#        [187.46156 ],
#        [188.2241  ],
#        [187.42244 ],
#        [185.69212 ],
#        [184.17833 ],
#        [186.15097 ],
#        [187.54475 ],
#        [185.34192 ],
#        [181.2974  ],
#        [179.01132 ],
#        [179.01456 ],
#        [181.66954 ],
#        [184.24571 ],
#        [183.37773 ],
#        [181.73578 ],
#        [178.8422  ],
#        [174.89836 ],
#        [171.70996 ],
#        [169.58167 ],
#        [168.7224  ],
#        [167.91902 ],
#        [167.41498 ],
#        [166.92763 ],
#        [172.38342 ],
#        [179.70665 ],
#        [183.23077 ],
#        [183.40448 ],
#        [180.30573 ],
#        [177.02684 ],
#        [175.24591 ],
#        [177.13467 ],
#        [180.78851 ],
#        [181.17296 ],
#        [178.10902 ],
#        [175.52286 ],
#        [176.92902 ],
#        [179.30768 ],
#        [178.69063 ],
#        [176.11908 ],
#        [172.51907 ],
#        [168.14452 ],
#        [167.29492 ],
#        [169.78299 ],
#        [172.40962 ],
#        [172.3717  ],
#        [172.69429 ],
#        [172.73125 ],
#        [170.73407 ],
#        [166.66109 ],
#        [162.87169 ],
#        [164.3828  ],
#        [165.30392 ],
#        [163.20341 ],
#        [158.67235 ],
#        [157.88246 ],
#        [161.7327  ],
#        [165.90607 ],
#        [169.31084 ],
#        [171.02777 ],
#        [172.6161  ],
#        [173.91463 ],
#        [176.32008 ],
#        [178.35538 ],
#        [179.66946 ],
#        [181.9576  ],
#        [183.11061 ],
#        [181.6296  ],
#        [179.89595 ],
#        [181.65112 ],
#        [182.51001 ],
#        [180.81897 ],
#        [179.29408 ],
#        [177.81142 ],
#        [174.87167 ],
#        [173.97794 ],
#        [176.1212  ],
#        [175.58943 ],
#        [173.74223 ],
#        [173.53941 ],
#        [174.00763 ],
#        [173.85185 ],
#        [170.85095 ],
#        [168.65079 ],
#        [164.8586  ],
#        [162.18723 ],
#        [165.4031  ],
#        [166.38985 ],
#        [165.53625 ],
#        [165.05504 ],
#        [168.34602 ],
#        [166.55101 ],
#        [163.17668 ],
#        [158.2989  ],
#        [156.66739 ],
#        [153.43098 ],
#        [149.0228  ],
#        [148.983   ],
#        [150.35431 ],
#        [153.19344 ],
#        [150.61615 ],
#        [144.56662 ],
#        [140.14725 ],
#        [141.64684 ],
#        [143.65536 ],
#        [144.43237 ],
#        [145.66376 ],
#        [149.31123 ],
#        [151.59343 ],
#        [151.58478 ],
#        [151.66467 ],
#        [148.85985 ],
#        [146.50378 ],
#        [147.28763 ],
#        [149.01985 ],
#        [147.59868 ],
#        [142.6713  ],
#        [136.25702 ],
#        [133.22191 ],
#        [134.97464 ],
#        [135.33678 ],
#        [135.1338  ],
#        [136.77148 ],
#        [137.95981 ],
#        [139.25964 ],
#        [141.34105 ],
#        [142.47917 ],
#        [140.22588 ],
#        [138.27792 ],
#        [136.50703 ],
#        [136.94527 ],
#        [139.77583 ],
#        [143.0455  ],
#        [146.49498 ],
#        [148.57582 ],
#        [147.73337 ],
#        [146.39    ],
#        [145.49324 ],
#        [146.91336 ],
#        [149.73657 ],
#        [150.20662 ],
#        [151.32256 ],
#        [153.46152 ],
#        [156.16444 ],
#        [157.05138 ],
#        [156.00246 ],
#        [154.0295  ],
#        [155.5608  ],
#        [158.47859 ],
#        [163.1362  ],
#        [165.67288 ],
#        [165.01526 ],
#        [166.51703 ],
#        [168.29793 ],
#        [168.97614 ],
#        [168.65416 ],
#        [168.29576 ],
#        [170.66417 ],
#        [172.84073 ],
#        [175.70207 ],
#        [178.06725 ],
#        [178.88272 ],
#        [179.43304 ],
#        [179.49498 ],
#        [177.9986  ],
#        [174.63759 ],
#        [172.34059 ],
#        [172.30286 ],
#        [174.86366 ],
#        [173.79973 ],
#        [170.33325 ],
#        [166.45111 ],
#        [163.62471 ],
#        [163.20021 ],
#        [162.88815 ],
#        [161.89095 ],
#        [161.70056 ],
#        [161.02744 ],
#        [161.71968 ],
#        [165.66547 ],
#        [163.72853 ],
#        [160.37885 ],
#        [156.8081  ],
#        [154.18367 ],
#        [155.48721 ],
#        [159.30249 ],
#        [160.426   ],
#        [158.95015 ],
#        [155.84096 ],
#        [153.78218 ],
#        [153.87248 ],
#        [153.88829 ],
#        [149.93867 ],
#        [143.96884 ],
#        [142.61205 ],
#        [146.24936 ],
#        [150.21841 ],
#        [151.30228 ],
#        [147.43558 ],
#        [143.19307 ],
#        [140.348   ],
#        [139.28448 ],
#        [141.93668 ],
#        [142.65126 ],
#        [143.77098 ],
#        [145.23341 ],
#        [145.97604 ],
#        [145.56404 ],
#        [146.6826  ],
#        [149.10294 ],
#        [152.25719 ],
#        [152.55177 ],
#        [148.95224 ],
#        [151.17522 ],
#        [154.24022 ],
#        [154.4839  ],
#        [150.44693 ],
#        [143.58578 ],
#        [139.12935 ],
#        [138.88718 ],
#        [141.19461 ],
#        [141.0372  ],
#        [145.54166 ],
#        [151.37083 ],
#        [153.42062 ],
#        [152.98766 ],
#        [150.84947 ],
#        [149.9104  ],
#        [150.45753 ],
#        [149.85432 ],
#        [150.28091 ],
#        [151.78967 ],
#        [151.64551 ],
#        [148.84789 ],
#        [144.8677  ],
#        [146.17958 ],
#        [149.6873  ],
#        [151.82301 ],
#        [151.36713 ],
#        [147.93462 ],
#        [143.84216 ],
#        [142.56017 ],
#        [143.1571  ],
#        [145.4276  ],
#        [147.7405  ],
#        [147.55276 ],
#        [142.71457 ],
#        [137.1198  ],
#        [133.25487 ],
#        [132.32288 ],
#        [134.88336 ],
#        [136.11772 ],
#        [135.53137 ],
#        [133.33588 ],
#        [129.38034 ],
#        [128.17404 ],
#        [129.13066 ],
#        [128.05344 ],
#        [126.865036],
#        [125.65422 ],
#        [127.15261 ],
#        [129.46005 ],
#        [130.98674 ],
#        [132.50125 ],
#        [133.14867 ],
#        [133.57133 ],
#        [134.2544  ],
#        [134.39423 ],
#        [134.2624  ],
#        [135.49103 ],
#        [138.53726 ],
#        [141.67238 ],
#        [142.87437 ],
#        [143.58022 ],
#        [144.83452 ],
#        [144.33035 ],
#        [143.91156 ],
#        [144.59657 ],
#        [148.36531 ],
#        [153.64565 ],
#        [155.40431 ],
#        [155.96312 ],
#        [154.48898 ],
#        [152.3542  ],
#        [151.35689 ],
#        [153.1824  ],
#        [155.2534  ],
#        [157.47472 ],
#        [157.85442 ],
#        [156.5563  ],
#        [153.12688 ],
#        [150.82048 ],
#        [150.75441 ],
#        [150.45451 ],
#        [150.77686 ],
#        [151.01491 ],
#        [149.9111  ],
#        [148.94724 ],
#        [151.16151 ],
#        [155.06854 ],
#        [156.26875 ],
#        [155.94296 ],
#        [153.9306  ],
#        [151.09987 ],
#        [150.53462 ],
#        [152.67154 ],
#        [155.21921 ],
#        [158.04843 ],
#        [159.09094 ],
#        [159.90292 ],
#        [161.20258 ],
#        [161.27167 ],
#        [161.27455 ],
#        [162.09018 ],
#        [161.94951 ],
#        [161.19048 ],
#        [162.39864 ],
#        [164.91318 ],
#        [168.02718 ],
#        [170.41388 ],
#        [170.8758  ],
#        [169.22125 ],
#        [168.04027 ],
#        [166.51764 ],
#        [165.1294  ],
#        [164.41403 ]], dtype=float32)

# %%
train_predict.shape
train_predict_reshaped = train_predict.reshape(1,train_predict.shape[0]).tolist()[0]
test_predict_reshaped = test_predict.reshape(1,test_predict.shape[0]).tolist()[0]
all_preds = train_predict_reshaped + test_predict_reshaped
print(len(all_preds))
#print(all_preds)
print(len(train_predict_reshaped))
print(len(test_predict_reshaped))
# Out:
# 2467
# 1621
# 846

# %%
df
# Out:
#             date ticker        open       close         low        high  \
# 0     2013-01-02   AAPL   19.779285   19.608213   19.821428   19.343929
# 1     2013-01-03   AAPL   19.567142   19.360714   19.631071   19.321428
# 2     2013-01-04   AAPL   19.177500   18.821428   19.236786   18.779642
# 3     2013-01-07   AAPL   18.642857   18.710714   18.903570   18.400000
# 4     2013-01-08   AAPL   18.900356   18.761070   18.996071   18.616072
# ...          ...    ...         ...         ...         ...         ...
# 2584  2023-04-10   AAPL  161.419998  162.029999  162.029999  160.080002
# 2585  2023-04-11   AAPL  162.350006  160.800003  162.360001  160.509995
# 2586  2023-04-12   AAPL  161.220001  160.100006  162.059998  159.779999
# 2587  2023-04-13   AAPL  161.630005  165.559998  165.800003  161.419998
# 2588  2023-04-14   AAPL  164.589996  165.210007  166.320007  163.820007
#
#            volume
# 0     560518000.0
# 1     352965180.0
# 2     594333570.0
# 3     484156420.0
# 4     458707200.0
# ...           ...
# 2584   47716900.0
# 2585   47644200.0
# 2586   50133100.0
# 2587   68445600.0
# 2588   49337200.0
#
# [2589 rows x 7 columns]

# %%
df.shape
# Out:
# (2589, 7)

# %%
print(len(all_preds)+60+60)
# Out:
# 2587

# %%
X_train2, y_train2 = create_dataset(train_data,1)
X_test2, y_test2 = create_dataset(test_data, 1)

# %%
# Reshape to include additional dimension
X_train2 = X_train2.reshape(X_train2.shape[0],X_train2.shape[1],1)
X_test2 = X_test2.reshape(X_test2.shape[0],X_test2.shape[1],1)

# %%
train_predict = model.predict(X_train2)
test_predict = model.predict(X_test2)
# Out:
# 53/53 [==============================] - 1s 887us/step
# 29/29 [==============================] - 0s 833us/step

# %%
train_predict.shape
train_predict_reshaped = train_predict.reshape(1,train_predict.shape[0]).tolist()[0]
test_predict_reshaped = test_predict.reshape(1,test_predict.shape[0]).tolist()[0]
all_preds = train_predict_reshaped + test_predict_reshaped
print(len(all_preds))
#print(all_preds)
print(len(train_predict_reshaped))
print(len(test_predict_reshaped))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train2,train_predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [419], in <cell line: 4>()
#       2 import math
#       3 from sklearn.metrics import mean_squared_error
# ----> 4 math.sqrt(mean_squared_error(y_train2,train_predict))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1680, 1621]

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(y_test2,test_predict))

# %%
len(test_predict)
# Out:
# 905

# %%
df.shape
# Out:
# (2589, 7)

# %%
df3 = df['date']
df3 = df3[df3.shape[0]-len(test_predict):df3.shape[0]]
df3
# Out:
# 1684    2019-09-11
# 1685    2019-09-12
# 1686    2019-09-13
# 1687    2019-09-16
# 1688    2019-09-17
#            ...
# 2584    2023-04-10
# 2585    2023-04-11
# 2586    2023-04-12
# 2587    2023-04-13
# 2588    2023-04-14
# Name: date, Length: 905, dtype: object

# %%
import db_manager as db
conn = db.connectToDB()
# Out:
# Connecting to the PostgreSQL database...

# %%
count = 0;
for date in df3:
    db.insertPrediction(date,'AAPL',test_predict,conn)
    count+=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [444], in <cell line: 1>()
#       1 for date in df3:
# ----> 2     db.insertPrediction(date,'AAPL',conn)
#
# AttributeError: module 'db_manager' has no attribute 'insertPrediction'
